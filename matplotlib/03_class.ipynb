# %% [markdown]
# ### Grid :

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [5, 10, 15, 20, 25]

plt.grid(axis="x", linewidth=2,
                   linestyle="dashed")

plt.plot(x, y)
plt.show()
